# %% [markdown]
# ## Genetic algorithm for the Travelling Salesman Problem
#
# In this notebook we will implement a genetic algorithm (GA) to solve the Travel Salesman Problem (TSP) in different configurations.
#
# Genetic algorithm's can be very different one to the others, but they all share common characteristics:
#
# - an encoding of solution candidates
# - a way to initialize a population
# - a way to evaluate the fitness of each individual
# - selection methods
# - genetic operators (mutations, crossovers, n-parents operators)
# - a termination criterion
#
#
# The code in this directory is divided as follows:
#
# - <code> main.cpp</code> contains the effective usage of the algorithm, to create the lists of cities and then saving the results
# - <code> tsp.h</code> and <code> tsp.cpp</code> contain all the used method and classes and their declaration

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### The object-oriented approach
#
# To create a program which performs a genetic algorithm to find the solution of the TSP, I decided to follow an object-oriented approach.
#
# I created four main classes: city, map, individual and population.
#
# - **city** is a simple class that contains the position of a city on a 2D plane and is able to print it out
#
# - **map** is more interesting, since is essentially a collection of cities, but is also able to create a specific configuration of them, i.e. on a circle of radius $r$ or inside a square of edge $l$. Moreover, the map class, once initialized with the list of the cities, calculates the $d$ matrix, namely the matrix that contains at the entry $d_{ij}$ the euclidean distance ($L_{1}$) between the i-th and the j-th city
#
# - **individual** is the class the contains a single solution candidate. It contains the tour encoded as a permutation of the cities and the lenght of the total tour. Through this class we can also perform the single parent mutation operators we have implemented.
#
# - **population** is more than a collection of individuals. Using the population class, we can effectively perform the genetic algorithm: we can sort the different members of the population by mean of their tour's lenght, we can select them using a _biased roulette wheel_ or preserving the most promising individuals through _elitism_

# %% [markdown]
# #### The mutation operators
#
# The mutation operators implemented are:
#
# - **single swap**: this operator choose randomly two cities inside an individual and swap them,e.g. $\left[ 1, 2, 3, 4, 5 \right] \to \left[ 1, 2, 4, 3, 5 \right]$ if we swap city $3$ and $4$, leaving always the first city fixed
#
# - **push backward swap**: this operator takes the first $n$ genes (after the starting city) and puts them at the end of the chromosome. For the problems studied below I chose $n=2$
#
# - **n-contiguous swap**: this operator randomly selects $n$ contiguous sites and swap them with other $n$. In the problems studied below I chose $n=3$
#
# - **uniform swap**: this operator cycles over all the genes of the chromosome and with probability $p_{u}$ swap it with another gene. This operator has a distributional bias, since the probability to swap $k$ genes goes with a Bernoullian distribution

# %% [markdown]
# #### Crossover
#
# The crossover operators selects two parents randomly (at this point there's no fitness-based crossover implemented)
#
# $$
# \left[ 1, 2, 3, 4, 5 \right]\\
# \left[ 1, 5, 4, 3, 2 \right]
# $$
#
# and performs a crossover in this way:
#
# 1. cut their paths at the samer random position (here after the third city):
#
#
# $$
# \left[ 1, 2, 3 | 4, 5 \right]\\
# \left[ 1, 5, 4 | 3, 2 \right]
# $$
#
#
# 2. conserve the first part of the paths:
# $$
# \left[ 1, 2, 3 | X, Y \right]\\
# \left[ 1, 5, 4 | X, Y \right]
# $$
#
#
# 3. complete the paths with the missing cities adding them in the **order** in which they appear in the consort:
#
#
# $$
# \left[ 1, 2, 3 | 5, 4 \right]\\
# \left[ 1, 5, 4 | 2, 3 \right]
# $$
#
#
# the two sons will replace the two parents (there's no surviving of the fittest between parents and children).
#
# The code implementing the crossover is the following
#
# ```c++
#
# void Crossover(individual * t1,individual * t2){
# 	vector<int> p1=t1->Get_genes();
# 	vector<int> p2=t2->Get_genes();
#
# 	int size=p1.size();
#
# 	vector<int> s1;
# 	vector<int> s2;
#
# 	uniform_int_distribution<> dist(0,size-1);
#
# 	int r=dist(mt);
#
# 	for(int i=0;i<r;i++){
# 		s1.push_back(p1[i]);
# 		s2.push_back(p2[i]);
# 	}
#
# 	for(int i=0;i<size;i++){
#
# 		int a=p1[i];
# 		int b=p2[i];
#
# 		if(any_of(p1.begin()+r,p1.end(),[b](int k){return k==b;})){
# 			s1.push_back(p2[i]);
# 		}
# 		if(any_of(p2.begin()+r,p2.end(),[a](int k){return k==a;})){
# 			s2.push_back(p1[i]);
# 		}
# 	}
#
# 	t1->Set_genes(s1);
# 	t2->Set_genes(s2);
# }
#
# ```
#
# Where the <code> algorithm </code> library is used to complete a parent with the missing cities using the order of the other.

# %% [markdown]
# #### The selection methods
#
# In this code I implemented inside the _population_ class two selection methods:
#
# - **classical roulette wheel selection**: this selection method is fitness based, since every individual will have a chance to survive to the next evolutive step based on the lenght of its tour. For every evolutive step $n_{pop}$ spins of the wheel are performed and every individual $i$ will have a probability
#
# $$
# p_{i}=\frac{1}{Z}\big(1-\frac{l_{i}}{l_{max}}\big)
# $$
#
#   to be chosen, where $Z = \sum_{i=1}^{n_{pop}} 1-\frac{l_{i}}{l_{max}}$ is the normalization factor.
#
# - **roulette wheel with elitism**: the same algorithm is performed, but now before performing crossovers, mutations and selection, the best $n_{elite}$ solution candidates are saved and passed to the next generation (after being saved, their copies will enter the modification and selection path together with the other candidates)

# %% [markdown]
# #### Initializing the cities
#
# After finishing writing the code, the first thing to do is to create a list of cities.
#
# Here I generated 32 cities
#
# - on a circumference of $r=10$
# - inside a square of $l=20$

# %%
circle=np.loadtxt("circle.dat")
square=np.loadtxt("square.dat")

xc=np.zeros(len(circle))
yc=np.zeros(len(circle))

xs=np.zeros(len(square))
ys=np.zeros(len(square))

for i in range(len(xc)):
    xc[i]=circle[i][0]
    yc[i]=circle[i][1]
    
for i in range(len(xs)):
    xs[i]=square[i][0]
    ys[i]=square[i][1]
    
    
##Plot

fig, (ax1,ax2)=plt.subplots(1,2,figsize=(13,6), dpi=80)

fig.suptitle("Cities generated for the TSP")

ax1.scatter(xc,yc)
ax1.set_title('Cities on a circle of $r=10$')
ax1.set(xlabel='x', ylabel='y')


ax2.scatter(xs,ys)
ax2.set_title('Cities in a square of $l=20$')
ax2.set(xlabel='x', ylabel='y')

plt.show()
plt.close()

# %% [markdown]
# #### The solutions of the cricle case
#
# We start studying the circle case, we apply to it both the classical roulette wheel and the elitism one.
#
# The population is chosen to be composed of $n_{ind}=1000$ inviduals and $n_{steps}=500$ evolutive steps are calculated. In the case of the elitism technique, the elite individuals are $n_{elite}=30$
#
# In both cases the probability of a mutation and of a crossover has to be carefully tuned, but performing the roulette wheel selection without saving some of the best results results generally in longer paths.
#
# - For the classic roulette case the probabilities of a mutation are $p_{s}=3\%, p_{pb}=6\%, p_{nc}=1\%$ and the probability of a crossover is $p_{c}=60\%$. In this case the uniform swap obstacolated the convergence and has been removed.
#
# - For the elitism case the probabilities of a mutation are $p_{s}=5\%, p_{pb}=5\%, p_{nc}=2\%, p_{u}=3\%$ and the probability of a crossover is $p_{c}=50\%$. Uniform swap has an intrisic probability of  $10\%$ per gene, this allows a better exploration of the landscape, while saving the best results prevent it from hindering the convergence. Generally using the elitism leads to more stable results.

# %%
# Now plot the results for the circle case

data1=open("results/best_circle_roulette.dat",'r').read().split('\n')
data2=open("results/best_circle_elitism.dat",'r').read().split('\n')
data3=open("results/average_circle_roulette.dat",'r').read().split('\n')
data4=open("results/average_circle_elitism.dat",'r').read().split('\n')

data1=[x.split(',') for x in data1]
data2=[x.split(',') for x in data2]
data3=[x.split(',') for x in data3]
data4=[x.split(',') for x in data4]


x1=[]
y1=[]
y2=[]
y3=[]
y4=[]

for i in range(len(data1)-1):
    x1.append(float(data1[i][0]))
    y1.append(float(data1[i][1]))
    y2.append(float(data2[i][1]))
    y3.append(float(data3[i][1]))
    y4.append(float(data4[i][1]))
    
fig, (ax1,ax2)=plt.subplots(1,2,figsize=(13,5), dpi=80)

fig.suptitle("Results for the TSP on a circumference")

ax1.plot(x1,y1,label='Classical roulette')
ax1.plot(x1,y2,label='Elitism')
ax1.set_title('Best path per generation with $L_{1}$ norm')
ax1.set(xlabel='Generation', ylabel='Tour lenght')
ax1.axhline(62)
ax1.legend()
ax1.grid(True)


ax2.plot(x1,y3,label='Classical roulette')
ax2.plot(x1,y4,label='Elitism')
ax2.set_title('Average path lenght per generation with $L_{1}$ norm')
ax2.set(xlabel='Generation', ylabel='Average lenght')
ax2.axhline(62)
ax2.legend()
ax2.grid(True)

plt.show()
plt.close()

# %% [markdown]
# As we can see, saving the best results per generation in a little elite is greatly improving the best path found, both for the best individual and on average.
#
# What we noted is that tuning the right parameters for the classical case is not so easy, since a too high mutation rate can prevent the convergence. On the contrary, with the elitism selection, we have more freedom on changing the parameters without preventing convergence.
#
# Here below we can see the best path found with elitism selection.

# %%
ce_best_ind=np.loadtxt("results/ind_circle_elitism.dat")
ce_best_ind=[int(x) for x in ce_best_ind]

xb=np.zeros(len(circle)+1)
yb=np.zeros(len(circle)+1)



for i in range(len(circle)):
    xb[i]=circle[ce_best_ind[i]][0]
    yb[i]=circle[ce_best_ind[i]][1]
    
xb[len(circle)]=xb[0]
yb[len(circle)]=yb[0]


plt.figure(figsize=(8,8))
plt.title("Best path found with elitism selection GA")
plt.plot(xb,yb, marker='o',linestyle='dashed')
plt.xlabel("x")
plt.ylabel("y")

plt.show()
plt.close()

# %% [markdown]
# #### The solutions of the square case
#
# Now we apply the same algorithms to solve the square case. Again, the uniform swap has been removed in the classical roulette case. The parameters for the classical case have been retuned: $p_{s}=2\%, p_{pb}=6\%, p_{nc}=2\%$ for mutation and $p_{c}=60\%$ for crossover. On the contrary, for the elitism case, the probabilities of a mutation and/or a crossover are kept the same as before.

# %%
data1=open("results/best_square_roulette.dat",'r').read().split('\n')
data2=open("results/best_square_elitism.dat",'r').read().split('\n')
data3=open("results/average_square_roulette.dat",'r').read().split('\n')
data4=open("results/average_square_elitism.dat",'r').read().split('\n')

data1=[x.split(',') for x in data1]
data2=[x.split(',') for x in data2]
data3=[x.split(',') for x in data3]
data4=[x.split(',') for x in data4]


x1=[]
y1=[]
y2=[]
y3=[]
y4=[]

for i in range(len(data1)-1):
    x1.append(float(data1[i][0]))
    y1.append(float(data1[i][1]))
    y2.append(float(data2[i][1]))
    y3.append(float(data3[i][1]))
    y4.append(float(data4[i][1]))
    
fig, (ax1,ax2)=plt.subplots(1,2,figsize=(13,5), dpi=80)

fig.suptitle("Results for the TSP inside a square")

ax1.plot(x1,y1,label='Classical roulette')
ax1.plot(x1,y2,label='Elitism')
ax1.set_title('Best path per generation with $L_{1}$ norm')
ax1.set(xlabel='Generation', ylabel='Tour lenght')
ax1.legend()
ax1.grid(True)


ax2.plot(x1,y3,label='Classical roulette')
ax2.plot(x1,y4,label='Elitism')
ax2.set_title('Average path lenght per generation with $L_{1}$ norm')
ax2.set(xlabel='Generation', ylabel='Average lenght')
ax2.legend()
ax2.grid(True)

plt.show()
plt.close()

# %% [markdown]
# We can see that both the methods have a fast convergence. The classical method is liable of worsening its performance over the generations, because there's no guarantee that the best subjects can survive.
#
# The fact that also the average curve of the elitism algorithm flattensa indicates that maybe $n_{elite}=30$ in this case are too many individuals, keeping them in many generations caused the population to be filled with copies of the optimal solution. In this case this is not a problem, since it's really difficult to find a better solution tha this, but in a general case the number of elements in the elit has to be tuned carefully. However, it is also important to notice that this behaviour is not so likely to appear: in this case the solution found was so good that overwhelmed all the others.
#
# In the case of random cities in a square there's no obvious shortest path to confront the results to, here below I plot a path found by the algorithm that uses elitism that seems quite reasonable.

# %%
se_best_ind=np.loadtxt("results/ind_square_elitism.dat")
se_best_ind=[int(x) for x in se_best_ind]

xc=[]
yc=[]



for i in range(len(square)-1):
    a=se_best_ind[i]
    xc.append(float(square[a][0]))
    yc.append(float(square[a][1]))

    
xc.append(xc[0])
yc.append(yc[0])


plt.figure(figsize=(8,8))
plt.title("Best path found with elitism selection GA")
plt.plot(xc,yc, marker='o',linestyle='dashed')
plt.xlabel("x")
plt.ylabel("y")

plt.show()
plt.close()

# %% [markdown]
# Therefore we can conclude that, in both cases, the application of the "elitism" heuristics guarantees best result, both on the best individual found and on average.
